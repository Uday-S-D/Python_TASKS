# %%
#TASK for FITBIT DATASET

# %%
#Read this dataset in pandas
import pandas as pd

# %%
df=pd.read_csv('FitBit_data1.csv')

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
# [457 rows x 15 columns]

# %%
#3. Convert all the dates available in dataset to timestamp format in pandas and in sql you to convert it in date format
df.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
df[['ActivityDate']]
# Out:
#     ActivityDate
# 0      3/25/2016
# 1      3/26/2016
# 2      3/27/2016
# 3      3/28/2016
# 4      3/29/2016
# ..           ...
# 452     4/8/2016
# 453     4/9/2016
# 454    4/10/2016
# 455    4/11/2016
# 456    4/12/2016
#
# [457 rows x 1 columns]

# %%
type(df[['ActivityDate']])
# Out:
# pandas.core.frame.DataFrame

# %%
df['ActivityDate']
# Out:
# 0      3/25/2016
# 1      3/26/2016
# 2      3/27/2016
# 3      3/28/2016
# 4      3/29/2016
#          ...
# 452     4/8/2016
# 453     4/9/2016
# 454    4/10/2016
# 455    4/11/2016
# 456    4/12/2016
# Name: ActivityDate, Length: 457, dtype: object

# %%
date = pd.to_datetime(df['ActivityDate'])

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
# [457 rows x 15 columns]

# %%
df['Time_stamp']= pd.to_datetime(df['ActivityDate'])

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#     Time_stamp
# 0   2016-03-25
# 1   2016-03-26
# 2   2016-03-27
# 3   2016-03-28
# 4   2016-03-29
# ..         ...
# 452 2016-04-08
# 453 2016-04-09
# 454 2016-04-10
# 455 2016-04-11
# 456 2016-04-12
#
# [457 rows x 16 columns]

# %%
df['ActivityDate']= pd.to_datetime(df['ActivityDate'])
df.dtypes
# Out:
# Id                                   int64
# ActivityDate                datetime64[ns]
# TotalSteps                           int64
# TotalDistance                      float64
# TrackerDistance                    float64
# LoggedActivitiesDistance           float64
# VeryActiveDistance                 float64
# ModeratelyActiveDistance           float64
# LightActiveDistance                float64
# SedentaryActiveDistance            float64
# VeryActiveMinutes                    int64
# FairlyActiveMinutes                  int64
# LightlyActiveMinutes                 int64
# SedentaryMinutes                     int64
# Calories                             int64
# Time_stamp                  datetime64[ns]
# dtype: object

# %%
4 . Find out in this data that how many unique id's we have
df['Id'].unique
# Out:
# <bound method Series.unique of 0      1503960366
# 1      1503960366
# 2      1503960366
# 3      1503960366
# 4      1503960366
#           ...
# 452    8877689391
# 453    8877689391
# 454    8877689391
# 455    8877689391
# 456    8877689391
# Name: Id, Length: 457, dtype: int64>

# %%
#5 . which id is one of the active id that you have in whole dataset
df.groupby('Id')['VeryActiveMinutes'].sum().idxmax()
# Out:
# 8053475328

# %%
df[df.dtypes[df.dtypes == 'int64'].index]
# Out:
#              Id  TotalSteps  VeryActiveMinutes  FairlyActiveMinutes  \
# 0    1503960366       11004                 33                   12
# 1    1503960366       17609                 89                   17
# 2    1503960366       12736                 56                    5
# 3    1503960366       13231                 39                   20
# 4    1503960366       12041                 28                   28
# ..          ...         ...                ...                  ...
# 452  8877689391       23014                 70                   29
# 453  8877689391       16470                 90                    9
# 454  8877689391       28497                128                   46
# 455  8877689391       10622                 18                    7
# 456  8877689391        2350                  0                    0
#
#      LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     205               804      1819
# 1                     274               588      2154
# 2                     268               605      1944
# 3                     224              1080      1932
# 4                     243               763      1886
# ..                    ...               ...       ...
# 452                   359               982      4196
# 453                   289              1052      3841
# 454                   211              1055      4526
# 455                   225              1190      2820
# 456                    58               531       938
#
# [457 rows x 7 columns]

# %%
#6.How many of them have not logged there activity find out in terms of number of ids
df.groupby('Id')['LoggedActivitiesDistance'].sum()<1
# Out:
# Id
# 1503960366     True
# 1624580081     True
# 1644430081     True
# 1844505072     True
# 1927972279     True
# 2022484408     True
# 2026352035     True
# 2320127002     True
# 2347167796     True
# 2873212765     True
# 2891001357    False
# 3372868164     True
# 3977333714     True
# 4020332650     True
# 4057192912     True
# 4319703577     True
# 4388161847     True
# 4445114986     True
# 4558609924     True
# 4702921684     True
# 5553957443     True
# 5577150313     True
# 6117666160     True
# 6290855005     True
# 6391747486    False
# 6775888955     True
# 6962181067    False
# 7007744171    False
# 7086361926     True
# 8053475328     True
# 8253242879     True
# 8378563200    False
# 8583815059     True
# 8792009665     True
# 8877689391     True
# Name: LoggedActivitiesDistance, dtype: bool

# %%
#7.Find out who is the laziest person id that we have in dataset
df.groupby('Id')['VeryActiveMinutes'].sum().idxmin()
# Out:
# 1927972279

# %%
#8. Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset (2200 calories/day)
df.groupby('Id')['Calories'].sum().apply(lambda x:x>2200*7).value_counts()
# Out:
# True     34
# False     1
# Name: Calories, dtype: int64

# %%
#9. how many person are not a regular person with respect to activity try to find out those
df[df['TotalSteps']==0]
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 51   1844505072     4/4/2016           0            0.0              0.0
# 52   1844505072     4/5/2016           0            0.0              0.0
# 59   1844505072    4/12/2016           0            0.0              0.0
# 96   2320127002     4/1/2016           0            0.0              0.0
# 97   2320127002     4/2/2016           0            0.0              0.0
# ..          ...          ...         ...            ...              ...
# 402  8253242879     4/2/2016           0            0.0              0.0
# 403  8253242879     4/3/2016           0            0.0              0.0
# 404  8253242879     4/4/2016           0            0.0              0.0
# 405  8253242879     4/5/2016           0            0.0              0.0
# 412  8253242879    4/12/2016           0            0.0              0.0
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 51                        0.0                 0.0                       0.0
# 52                        0.0                 0.0                       0.0
# 59                        0.0                 0.0                       0.0
# 96                        0.0                 0.0                       0.0
# 97                        0.0                 0.0                       0.0
# ..                        ...                 ...                       ...
# 402                       0.0                 0.0                       0.0
# 403                       0.0                 0.0                       0.0
# 404                       0.0                 0.0                       0.0
# 405                       0.0                 0.0                       0.0
# 412                       0.0                 0.0                       0.0
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 51                   0.0                      0.0                  0
# 52                   0.0                      0.0                  0
# 59                   0.0                      0.0                  0
# 96                   0.0                      0.0                  0
# 97                   0.0                      0.0                  0
# ..                   ...                      ...                ...
# 402                  0.0                      0.0                  0
# 403                  0.0                      0.0                  0
# 404                  0.0                      0.0                  0
# 405                  0.0                      0.0                  0
# 412                  0.0                      0.0                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 51                     0                     0               669      1347
# 52                     0                     0              1440      1347
# 59                     0                     0               426       399
# 96                     0                     0              1440      1324
# 97                     0                     0              1440      1324
# ..                   ...                   ...               ...       ...
# 402                    0                     0              1440      1429
# 403                    0                     0              1440      1429
# 404                    0                     0              1440      1429
# 405                    0                     0              1440      1429
# 412                    0                     0              1440         0
#
#     Time_stamp
# 51  2016-04-04
# 52  2016-04-05
# 59  2016-04-12
# 96  2016-04-01
# 97  2016-04-02
# ..         ...
# 402 2016-04-02
# 403 2016-04-03
# 404 2016-04-04
# 405 2016-04-05
# 412 2016-04-12
#
# [61 rows x 16 columns]

# %%
#10 . Who is the third most active person in this dataset find out those in pandas and in sql both
df.groupby('Id')['VeryActiveMinutes'].sum().sort_values(ascending=False)[2:3]
# Out:
# Id
# 8877689391    802
# Name: VeryActiveMinutes, dtype: int64

# %%
#using SQL Query
#select id, sum(VeryActiveMinutes) from fitbit_data group by Id ORDER BY sum(VeryActiveMinutes) DESC LIMIT 1 OFFSET 2;

# %%
#11 . who is the 5th most laziest person avilable in dataset find it out
df.groupby('Id')['SedentaryMinutes'].sum().sort_values()[4:5]
# Out:
# Id
# 6962181067    8488
# Name: SedentaryMinutes, dtype: int64

# %%
#12 . what is a total cummulative calories burn for a person find out
df.groupby('Id')['Calories'].sum()
# Out:
# Id
# 1503960366    34128
# 1624580081    25705
# 1644430081    29164
# 1844505072    19391
# 1927972279    27048
# 2022484408    29704
# 2026352035    16266
# 2320127002    18385
# 2347167796    30320
# 2873212765    20349
# 2891001357    18187
# 3372868164    18603
# 3977333714    16777
# 4020332650    98412
# 4057192912    60913
# 4319703577    23931
# 4388161847    14442
# 4445114986    31617
# 4558609924    21962
# 4702921684    42322
# 5553957443    21630
# 5577150313    36303
# 6117666160    20993
# 6290855005    21656
# 6391747486    15868
# 6775888955    24523
# 6962181067    29249
# 7007744171    31525
# 7086361926    26124
# 8053475328    31825
# 8253242879    17556
# 8378563200    40274
# 8583815059    19130
# 8792009665    24884
# 8877689391    41414
# Name: Calories, dtype: int64
